# %% [markdown]
# # Kualitas Udara di Jakarta Selama Pandemi COVID-19

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# ### Data Kualitas Udara (2017-2021)

# %% [markdown]
# #### 2017

# %%
januari_2017 = pd.read_csv('./Datasets/Raw Data/2017/indeks-standar-pencemar-udara-di-spku-bulan-januari-tahun-2017.csv',
                          usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
februari_2017 = pd.read_csv('./Datasets/Raw Data/2017/indeks-standar-pencemar-udara-di-spku-bulan-februari-tahun-2017.csv',
                           usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
maret_2017 = pd.read_csv('./Datasets/Raw Data/2017/indeks-standar-pencemar-udara-di-spku-bulan-maret-tahun-2017.csv',
                        usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
april_2017 = pd.read_csv('./Datasets/Raw Data/2017/indeks-standar-pencemar-udara-di-spku-bulan-april-tahun-2017.csv',
                        usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
mei_2017 = pd.read_csv('./Datasets/Raw Data/2017/indeks-standar-pencemar-udara-di-spku-bulan-mei-tahun-2017.csv',
                      usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
juni_2017 = pd.read_csv('./Datasets/Raw Data/2017/indeks-standar-pencemar-udara-di-spku-bulan-juni-tahun-2017.csv',
                       usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
juli_2017 = pd.read_csv('./Datasets/Raw Data/2017/indeks-standar-pencemar-udara-di-spku-bulan-juli-tahun-2017.csv',
                       usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
agustus_2017 = pd.read_csv('./Datasets/Raw Data/2017/indeks-standar-pencemar-udara-di-spku-bulan-agustus-tahun-2017.csv',
                          usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
september_2017 = pd.read_csv('./Datasets/Raw Data/2017/indeks-standar-pencemar-udara-di-spku-bulan-september-tahun-2017.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
oktober_2017 = pd.read_csv('./Datasets/Raw Data/2017/indeks-standar-pencemar-udara-di-spku-bulan-oktober-tahun-2017.csv',
                          usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
november_2017 = pd.read_csv('./Datasets/Raw Data/2017/indeks-standar-pencemar-udara-di-spku-bulan-november-tahun-2017.csv',
                           usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
desember_2017 = pd.read_csv('./Datasets/Raw Data/2017/indeks-standar-pencemar-udara-di-spku-bulan-desember-tahun-2017.csv',
                           usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])

# %% [markdown]
# #### 2018

# %%
januari_2018 = pd.read_csv('./Datasets/Raw Data/2018/data-indeks-standar-pencemar-udara-di-spku-bulan-januari-tahun-2018.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
februari_2018 = pd.read_csv('./Datasets/Raw Data/2018/data-indeks-standar-pencemar-udara-di-spku-bulan-februari-tahun-2018.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
maret_2018 = pd.read_csv('./Datasets/Raw Data/2018/data-indeks-standar-pencemar-udara-di-spku-bulan-maret-tahun-2018.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
april_2018 = pd.read_csv('./Datasets/Raw Data/2018/data-indeks-standar-pencemar-udara-di-spku-bulan-april-tahun-2018.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
mei_2018 = pd.read_csv('./Datasets/Raw Data/2018/data-indeks-standar-pencemar-udara-di-spku-bulan-mei-tahun-2018.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
juni_2018 = pd.read_csv('./Datasets/Raw Data/2018/data-indeks-standar-pencemar-udara-di-spku-bulan-juni-tahun-2018.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
juli_2018 = pd.read_csv('./Datasets/Raw Data/2018/data-indeks-standar-pencemar-udara-di-spku-bulan-juli-tahun-2018.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
agustus_2018 = pd.read_csv('./Datasets/Raw Data/2018/data-indeks-standar-pencemar-udara-di-spku-bulan-agustus-tahun-2018.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
september_2018 = pd.read_csv('./Datasets/Raw Data/2018/data-indeks-standar-pencemar-udara-di-spku-bulan-september-tahun-2018.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
oktober_2018 = pd.read_csv('./Datasets/Raw Data/2018/data-indeks-standar-pencemar-udara-di-spku-bulan-oktober-tahun-2018.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
november_2018 = pd.read_csv('./Datasets/Raw Data/2018/data-indeks-standar-pencemar-udara-di-spku-bulan-november-tahun-2018.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
desember_2018 = pd.read_csv('./Datasets/Raw Data/2018/indeks-standar-pencemar-udara-di-spku-bulan-desember-tahun-2018.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])

# %% [markdown]
# #### 2019

# %%
januari_2019 = pd.read_csv('./Datasets/Raw Data/2019/indeks-standar-pencemar-udara-di-spku-bulan-januari-tahun-2019.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
februari_2019 = pd.read_csv('./Datasets/Raw Data/2019/indeks-standar-pencemar-udara-di-spku-bulan-februari-tahun-2019.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
maret_2019 = pd.read_csv('./Datasets/Raw Data/2019/indeks-standar-pencemar-udara-di-spku-bulan-maret-tahun-2019.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
april_2019 = pd.read_csv('./Datasets/Raw Data/2019/indeks-standar-pencemar-udara-di-spku-bulan-april-tahun-2019.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
mei_2019 = pd.read_csv('./Datasets/Raw Data/2019/indeks-standar-pencemar-udara-di-spku-bulan-mei-tahun-2019.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
juni_2019 = pd.read_csv('./Datasets/Raw Data/2019/indeks-standar-pencemar-udara-di-spku-bulan-juni-tahun-2019.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
juli_2019 = pd.read_csv('./Datasets/Raw Data/2019/indeks-standar-pencemar-udara-di-spku-bulan-juli-tahun-2019.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
agustus_2019 = pd.read_csv('./Datasets/Raw Data/2019/indeks-standar-pencemar-udara-di-spku-bulan-agustus-tahun-2019.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
september_2019 = pd.read_csv('./Datasets/Raw Data/2019/indeks-standar-pencemar-udara-di-spku-bulan-september-tahun-2019.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
oktober_2019 = pd.read_csv('./Datasets/Raw Data/2019/indeks-standar-pencemar-udara-di-spku-bulan-oktober-tahun-2019.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
november_2019 = pd.read_csv('./Datasets/Raw Data/2019/indeks-standar-pencemar-udara-di-spku-bulan-november-tahun-2019.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
desember_2019 = pd.read_csv('./Datasets/Raw Data/2019/indeks-standar-pencemar-udara-di-spku-bulan-desember-tahun-2019.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])

# %% [markdown]
# #### 2020

# %%
januari_2020 = pd.read_csv('./Datasets/Raw Data/2020/indeks-standar-pencemar-udara-di-spku-bulan-januari-tahun-2020.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
februari_2020 = pd.read_csv('./Datasets/Raw Data/2020/indeks-standar-pencemar-udara-di-spku-bulan-februari-tahun-2020.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
maret_2020 = pd.read_csv('./Datasets/Raw Data/2020/indeks-standar-pencemar-udara-di-spku-bulan-maret-tahun-2020.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
april_2020 = pd.read_csv('./Datasets/Raw Data/2020/indeks-standar-pencemar-udara-di-spku-bulan-april-tahun-2020.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
mei_2020 = pd.read_csv('./Datasets/Raw Data/2020/indeks-standar-pencemar-udara-di-spku-bulan-mei-tahun-2020.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
juni_2020 = pd.read_csv('./Datasets/Raw Data/2020/indeks-standar-pencemar-udara-di-spku-bulan-juni-tahun-2020.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
juli_2020 = pd.read_csv('./Datasets/Raw Data/2020/indeks-standar-pencemar-udara-di-spku-bulan-juli-tahun-2020.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
agustus_2020 = pd.read_csv('./Datasets/Raw Data/2020/indeks-standar-pencemar-udara-di-spku-bulan-agustus-tahun-2020.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
september_2020 = pd.read_csv('./Datasets/Raw Data/2020/indeks-standar-pencemar-udara-di-spku-bulan-september-tahun-2020.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
oktober_2020 = pd.read_csv('./Datasets/Raw Data/2020/indeks-standar-pencemar-udara-di-spku-bulan-oktober-tahun-2020.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
november_2020 = pd.read_csv('./Datasets/Raw Data/2020/indeks-standar-pencemar-udara-di-spku-bulan-november-tahun-2020.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
desember_2020 = pd.read_csv('./Datasets/Raw Data/2020/indeks-standar-pencemar-udara-di-spku-bulan-desember-tahun-2020.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])

# %% [markdown]
# #### 2021

# %%
januari_2021 = pd.read_csv('./Datasets/Raw Data/2021/indeks-standar-pencemar-udara-di-spku-bulan-januari-tahun-2021.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
februari_2021 = pd.read_csv('./Datasets/Raw Data/2021/indeks-standar-pencemar-udara-di-spku-bulan-februari-tahun-2021.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
maret_2021 = pd.read_csv('./Datasets/Raw Data/2021/indeks-standar-pencemar-udara-di-spku-bulan-maret-tahun-2021.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
april_2021 = pd.read_csv('./Datasets/Raw Data/2021/indeks-standar-pencemar-udara-di-spku-bulan-april-tahun-2021.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
mei_2021 = pd.read_csv('./Datasets/Raw Data/2021/indeks-standar-pencemar-udara-di-spku-bulan-mei-tahun-2021.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
juni_2021 = pd.read_csv('./Datasets/Raw Data/2021/indeks-standar-pencemar-udara-di-spku-bulan-juni-tahun-2021.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
juli_2021 = pd.read_csv('./Datasets/Raw Data/2021/indeks-standar-pencemar-udara-di-spku-bulan-juli-tahun-2021.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
agustus_2021 = pd.read_csv('./Datasets/Raw Data/2021/indeks-standar-pencemar-udara-di-spku-bulan-agustus-tahun-2021.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
september_2021 = pd.read_csv('./Datasets/Raw Data/2021/indeks-standar-pencemar-udara-di-spku-bulan-september-tahun-2021.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
oktober_2021 = pd.read_csv('./Datasets/Raw Data/2021/indeks-standar-pencemar-udara-di-spku-bulan-oktober-tahun-2021.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
november_2021 = pd.read_csv('./Datasets/Raw Data/2021/indeks-standar-pencemar-udara-di-spku-bulan-november-tahun-2021.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])
desember_2021 = pd.read_csv('./Datasets/Raw Data/2021/indeks-standar-pencemar-udara-di-spku-bulan-desember-tahun-2021.csv',
                            usecols=['tanggal', 'stasiun', 'pm10', 'so2', 'co', 'o3', 'no2', 'max','critical', 'categori'])

# %% [markdown]
# ### Integrating Data Kualitas Udara

# %%
kualitas_udara_2017 = pd.concat([januari_2017,februari_2017,maret_2017,april_2017,mei_2017,juni_2017,
                                 juli_2017,agustus_2017,september_2017,oktober_2017,november_2017,desember_2017])
kualitas_udara_2018 = pd.concat([januari_2018,februari_2018,maret_2018,april_2018,mei_2018,juni_2018,
                                 juli_2018,agustus_2018,september_2018,oktober_2018,november_2018,desember_2018])
kualitas_udara_2019 = pd.concat([januari_2019,februari_2019,maret_2019,april_2019,mei_2019,juni_2019,
                                 juli_2019,agustus_2019,september_2019,oktober_2019,november_2019,desember_2019])
kualitas_udara_2020 = pd.concat([januari_2020,februari_2020,maret_2020,april_2020,mei_2020,juni_2020,
                                 juli_2020,agustus_2020,september_2020,oktober_2020,november_2020,desember_2020])
kualitas_udara_2021 = pd.concat([januari_2021,februari_2021,maret_2021,april_2021,mei_2021,juni_2021,
                                 juli_2021,agustus_2021,september_2021,oktober_2021,november_2021,desember_2021])

# %%
data_kualitas_udara = pd.concat([kualitas_udara_2017,kualitas_udara_2018,kualitas_udara_2019,kualitas_udara_2020,
                                kualitas_udara_2021])

# %%
data_kualitas_udara.to_csv('data_kualitas_udara_2017_2021.csv',index=False)

# %%
data_kualitas_udara = pd.read_csv('./Datasets/Raw Data/data_kualitas_udara_2017_2021.csv')
data_kualitas_udara
# Out:
#          tanggal                           stasiun pm10 so2  co  o3 no2   max  \
# 0     2017-01-01                DKI1 (Bunderan HI)   63  34  25  21   2  63.0
# 1     2017-01-02                DKI1 (Bunderan HI)   16  32  16  19   1  32.0
# 2     2017-01-03                DKI1 (Bunderan HI)   18  32  17  20   2  32.0
# 3     2017-01-04                DKI1 (Bunderan HI)   24  32  22  20   2  32.0
# 4     2017-01-05                DKI1 (Bunderan HI)   29  32  25  14   2  32.0
# ...          ...                               ...  ...  ..  ..  ..  ..   ...
# 9044  2021-12-27  DKI5 (Kebon Jeruk) Jakarta Barat   54  36  14  21  47    76
# 9045  2021-12-28  DKI5 (Kebon Jeruk) Jakarta Barat   44  20  11  21  33    68
# 9046  2021-12-29  DKI5 (Kebon Jeruk) Jakarta Barat   34  28   8  25  29    54
# 9047  2021-12-30  DKI5 (Kebon Jeruk) Jakarta Barat   53  25  15  23  44    75
# 9048  2021-12-31  DKI5 (Kebon Jeruk) Jakarta Barat   60  28  19  30  53    87
#
#      critical categori
# ...

# %% [markdown]
# ### Data Kasus COVID-19 (2020-2021)

# %%
data_covid = pd.read_excel('./Datasets/Raw Data/KasusCovid19-Jakarta.xlsx',
                          usecols=['Tanggal','Meninggal','Sembuh','Self Isolation','Total Pasien','Positif Aktif'])
data_covid
# Out:
#        Tanggal  Meninggal  Sembuh  Self Isolation  Total Pasien  Positif Aktif
# 0   2020-03-01          0       0               0             0              0
# 1   2020-03-02          0       0               0             0              0
# 2   2020-03-03          1       0               0             3              2
# 3   2020-03-04          1       0               0             3              2
# 4   2020-03-05          3       0               0             7              4
# ..         ...        ...     ...             ...           ...            ...
# 666 2021-12-27      13584  851096             171        865034            354
# 667 2021-12-28      13585  851138             236        865130            407
# 668 2021-12-29      13587  851167             238        865157            403
# 669 2021-12-30      13587  851201             251        865210            422
# 670 2021-12-31      13588  851222             295        865297            487
#
# [671 rows x 6 columns]

# %% [markdown]
# ## Data Cleansing (Data Kualitas Udara)

# %%
data_kualitas_udara.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9049 entries, 0 to 9048
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   9014 non-null   object
#  1   stasiun   9014 non-null   object
#  2   pm10      8963 non-null   object
#  3   so2       8947 non-null   object
#  4   co        8953 non-null   object
#  5   o3        8904 non-null   object
#  6   no2       8915 non-null   object
#  7   max       8982 non-null   object
#  8   critical  8883 non-null   object
#  9   categori  9013 non-null   object
# dtypes: object(10)
# memory usage: 707.1+ KB

# %% [markdown]
# ### Missing Values

# %%
data_kualitas_udara.isnull().sum()
# Out:
# tanggal      35
# stasiun      35
# pm10         86
# so2         102
# co           96
# o3          145
# no2         134
# max          67
# critical    166
# categori     36
# dtype: int64

# %% [markdown]
# ### Modifying NaN Value

# %%
# Modifying nan value
data_kualitas_udara = data_kualitas_udara.replace('---',np.nan)

# %%
data_kualitas_udara.isnull().sum()
# Out:
# tanggal      35
# stasiun      38
# pm10        412
# so2         401
# co          339
# o3          386
# no2         387
# max          67
# critical    166
# categori     36
# dtype: int64

# %%
data_kualitas_udara.dropna(inplace=True)

# %% [markdown]
# ### Handling 'TIDAK ADA DATA'

# %%
data_kualitas_udara = data_kualitas_udara[data_kualitas_udara['categori'] != 'TIDAK ADA DATA']

# %% [markdown]
# ### Transforming Datetime Variables

# %%
data_kualitas_udara['tanggal'] = pd.to_datetime(data_kualitas_udara['tanggal'])
# Out:
# C:\Users\denny\anaconda3\envs\py39\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/11/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\denny\anaconda3\envs\py39\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/11/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\denny\anaconda3\envs\py39\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/11/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %% [markdown]
# ### Transforming Numerical Variables

# %%
data_kualitas_udara.head()
# Out:
#      tanggal             stasiun pm10 so2  co  o3 no2   max critical categori
# 0 2017-01-01  DKI1 (Bunderan HI)   63  34  25  21   2  63.0     PM10   SEDANG
# 1 2017-01-02  DKI1 (Bunderan HI)   16  32  16  19   1  32.0      SO2     BAIK
# 2 2017-01-03  DKI1 (Bunderan HI)   18  32  17  20   2  32.0      SO2     BAIK
# 3 2017-01-04  DKI1 (Bunderan HI)   24  32  22  20   2  32.0      SO2     BAIK
# 4 2017-01-05  DKI1 (Bunderan HI)   29  32  25  14   2  32.0      SO2     BAIK

# %%
# Modifying types
data_kualitas_udara['pm10'] = data_kualitas_udara['pm10'].astype(str).astype(float)
data_kualitas_udara['so2'] = data_kualitas_udara['so2'].astype(str).astype(float)
data_kualitas_udara['co'] = data_kualitas_udara['co'].astype(str).astype(float)
data_kualitas_udara['o3'] = data_kualitas_udara['o3'].astype(str).astype(float)
data_kualitas_udara['no2'] = data_kualitas_udara['no2'].astype(str).astype(float)
data_kualitas_udara['max'] = data_kualitas_udara['max'].astype(str).astype(float)

# %%
data_kualitas_udara.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7937 entries, 0 to 9048
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   7937 non-null   datetime64[ns]
#  1   stasiun   7937 non-null   object
#  2   pm10      7937 non-null   float64
#  3   so2       7937 non-null   float64
#  4   co        7937 non-null   float64
#  5   o3        7937 non-null   float64
#  6   no2       7937 non-null   float64
#  7   max       7937 non-null   float64
#  8   critical  7937 non-null   object
#  9   categori  7937 non-null   object
# dtypes: datetime64[ns](1), float64(6), object(3)
# memory usage: 682.1+ KB

# %% [markdown]
# ### Duplicate Data

# %%
data_kualitas_udara.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Resetting Index

# %%
data_kualitas_udara = data_kualitas_udara.reset_index(drop=True)

# %% [markdown]
# ## Data Cleansing (Data COVID-19)

# %%
data_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Tanggal         671 non-null    datetime64[ns]
#  1   Meninggal       671 non-null    int64
#  2   Sembuh          671 non-null    int64
#  3   Self Isolation  671 non-null    int64
#  4   Total Pasien    671 non-null    int64
#  5   Positif Aktif   671 non-null    int64
# dtypes: datetime64[ns](1), int64(5)
# memory usage: 31.6 KB

# %%
data_covid.describe()
# Out:
#           Meninggal         Sembuh  Self Isolation   Total Pasien  \
# count    671.000000     671.000000      671.000000     671.000000
# mean    5693.555887  331112.245902     7948.290611  348316.239940
# std     4977.986634  323387.370013    13623.461571  330440.860765
# min        0.000000       0.000000        0.000000       0.000000
# 25%      993.000000   19341.000000     1436.500000   29295.000000
# 50%     4254.000000  238395.000000     4201.000000  266244.000000
# 75%     9873.500000  609836.500000     8232.500000  732100.000000
# max    13588.000000  851222.000000    88295.000000  865297.000000
#
#        Positif Aktif
# count     671.000000
# mean    11510.438152
# std     18019.657946
# min         0.000000
# 25%      3317.000000
# 50%      7179.000000
# 75%     12138.500000
# max    113138.000000

# %%
data_covid.isnull().sum()
# Out:
# Tanggal           0
# Meninggal         0
# Sembuh            0
# Self Isolation    0
# Total Pasien      0
# Positif Aktif     0
# dtype: int64

# %%
data_covid.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### **Data Kualitas Udara**

# %% [markdown]
# ### Dividing Numerical and Categorical Variable

# %%
num_data_kualitas = data_kualitas_udara.select_dtypes(exclude='object')
cat_data_kualitas = data_kualitas_udara.select_dtypes(include='object')

# %%
num_data_kualitas
# Out:
#         tanggal  pm10   so2    co    o3   no2   max
# 0    2017-01-01  63.0  34.0  25.0  21.0   2.0  63.0
# 1    2017-01-02  16.0  32.0  16.0  19.0   1.0  32.0
# 2    2017-01-03  18.0  32.0  17.0  20.0   2.0  32.0
# 3    2017-01-04  24.0  32.0  22.0  20.0   2.0  32.0
# 4    2017-01-05  29.0  32.0  25.0  14.0   2.0  32.0
# ...         ...   ...   ...   ...   ...   ...   ...
# 7932 2021-12-27  54.0  36.0  14.0  21.0  47.0  76.0
# 7933 2021-12-28  44.0  20.0  11.0  21.0  33.0  68.0
# 7934 2021-12-29  34.0  28.0   8.0  25.0  29.0  54.0
# 7935 2021-12-30  53.0  25.0  15.0  23.0  44.0  75.0
# 7936 2021-12-31  60.0  28.0  19.0  30.0  53.0  87.0
#
# [7937 rows x 7 columns]

# %%
cat_data_kualitas
# Out:
#                                stasiun critical categori
# 0                   DKI1 (Bunderan HI)     PM10   SEDANG
# 1                   DKI1 (Bunderan HI)      SO2     BAIK
# 2                   DKI1 (Bunderan HI)      SO2     BAIK
# 3                   DKI1 (Bunderan HI)      SO2     BAIK
# 4                   DKI1 (Bunderan HI)      SO2     BAIK
# ...                                ...      ...      ...
# 7932  DKI5 (Kebon Jeruk) Jakarta Barat     PM25   SEDANG
# 7933  DKI5 (Kebon Jeruk) Jakarta Barat     PM25   SEDANG
# 7934  DKI5 (Kebon Jeruk) Jakarta Barat     PM25   SEDANG
# 7935  DKI5 (Kebon Jeruk) Jakarta Barat     PM25   SEDANG
# 7936  DKI5 (Kebon Jeruk) Jakarta Barat     PM25   SEDANG
#
# [7937 rows x 3 columns]

# %%
num_data_kualitas.describe()
# Out:
#               pm10          so2           co           o3          no2  \
# count  7937.000000  7937.000000  7937.000000  7937.000000  7937.000000
# mean     51.896686    24.446012    17.761749    61.052665    13.485448
# std      16.749719    13.596945    13.307148    36.481218    14.097437
# min       2.000000     1.000000     1.000000     2.000000     1.000000
# 25%      42.000000    15.000000    10.000000    32.000000     6.000000
# 50%      54.000000    21.000000    15.000000    56.000000    10.000000
# 75%      63.000000    31.000000    21.000000    82.000000    15.000000
# max     179.000000   112.000000   197.000000   243.000000   197.000000
#
#                max
# count  7937.000000
# mean     73.654403
# std      32.440289
# min       1.000000
# 25%      54.000000
# 50%      71.000000
# 75%      89.000000
# max     243.000000

# %%
cat_data_kualitas[['categori']].describe()
# Out:
#        categori
# count      7937
# unique        4
# top      SEDANG
# freq       5315

# %% [markdown]
# ### Unique Values

# %%
cat_data_kualitas['stasiun'].unique()
# Out:
# array(['DKI1 (Bunderan HI)', 'DKI2 (Kelapa Gading)', 'DKI3 (Jagakarsa)',
#        'DKI4 (Lubang Buaya)', 'DKI5 (Kebon Jeruk)',
#        'DKI5 (Kebon Jeruk) Jakarta Barat', '45', '34', '59', '56', '35',
#        '36', '37', '39', '30', '40', '48', '64', '50', '41', '44', '62',
#        '43', '58', '33', '49', '61', '47', '51', '42', '55', '54', '65',
#        '53', '27', '71', '52', '63', '60', '66', '38', '32', '74', '76',
#        '70', '89', '69', '101', '57', '73', '78', '24', '25'],
#       dtype=object)

# %%
cat_data_kualitas['critical'].unique()
# Out:
# array(['PM10', 'SO2', 'O3', 'CO', 'PM25', 'NO2'], dtype=object)

# %%
cat_data_kualitas['categori'].unique()
# Out:
# array(['SEDANG', 'BAIK', 'TIDAK SEHAT', 'SANGAT TIDAK SEHAT'],
#       dtype=object)

# %% [markdown]
# ### Variable Proporsion

# %%
cat_data_kualitas['categori'].value_counts()
# Out:
# SEDANG                5315
# BAIK                  1358
# TIDAK SEHAT           1227
# SANGAT TIDAK SEHAT      37
# Name: categori, dtype: int64

# %%
cat_data_kualitas['critical'].value_counts()
# Out:
# O3      4032
# PM10    1792
# PM25    1700
# CO       259
# SO2      153
# NO2        1
# Name: critical, dtype: int64

# %%
cat_data_kualitas['stasiun'].value_counts()
# Out:
# DKI1 (Bunderan HI)                  1622
# DKI2 (Kelapa Gading)                1622
# DKI3 (Jagakarsa)                    1530
# DKI4 (Lubang Buaya)                 1505
# DKI5 (Kebon Jeruk) Jakarta Barat    1185
# DKI5 (Kebon Jeruk)                   347
# 43                                     8
# 34                                     7
# 40                                     7
# 44                                     6
# 48                                     5
# 51                                     5
# 58                                     4
# 56                                     4
# 53                                     4
# 54                                     4
# 50                                     4
# 45                                     4
# 32                                     3
# 38                                     3
# 65                                     3
# 47                                     3
# 59                                     3
# ...

# %% [markdown]
# ### Data COVID-19

# %%
data_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Tanggal         671 non-null    datetime64[ns]
#  1   Meninggal       671 non-null    int64
#  2   Sembuh          671 non-null    int64
#  3   Self Isolation  671 non-null    int64
#  4   Total Pasien    671 non-null    int64
#  5   Positif Aktif   671 non-null    int64
# dtypes: datetime64[ns](1), int64(5)
# memory usage: 31.6 KB

# %%
data_covid.describe()
# Out:
#           Meninggal         Sembuh  Self Isolation   Total Pasien  \
# count    671.000000     671.000000      671.000000     671.000000
# mean    5693.555887  331112.245902     7948.290611  348316.239940
# std     4977.986634  323387.370013    13623.461571  330440.860765
# min        0.000000       0.000000        0.000000       0.000000
# 25%      993.000000   19341.000000     1436.500000   29295.000000
# 50%     4254.000000  238395.000000     4201.000000  266244.000000
# 75%     9873.500000  609836.500000     8232.500000  732100.000000
# max    13588.000000  851222.000000    88295.000000  865297.000000
#
#        Positif Aktif
# count     671.000000
# mean    11510.438152
# std     18019.657946
# min         0.000000
# 25%      3317.000000
# 50%      7179.000000
# 75%     12138.500000
# max    113138.000000

# %% [markdown]
# ## Data Visualization

# %%
fig,ax = plt.subplots(figsize=(12,6))
ax = sns.lineplot(data = data_kualitas_udara[['tanggal','pm10']].set_index('tanggal').resample('M').sum(), palette=['red'])
ax1 = sns.lineplot(data = data_kualitas_udara[['tanggal','so2']].set_index('tanggal').resample('M').sum(), palette = ['green'])
ax2 = sns.lineplot(data = data_kualitas_udara[['tanggal','co']].set_index('tanggal').resample('M').sum(), palette = ['blue'])
ax3 = sns.lineplot(data = data_kualitas_udara[['tanggal','no2']].set_index('tanggal').resample('M').sum(), palette = ['black'])
ax4 = sns.lineplot(data = data_kualitas_udara[['tanggal','o3']].set_index('tanggal').resample('M').sum(), palette = ['purple'])
plt.title('Penyebaran Partikulat tiap bulan (2017-2021)')
plt.grid()
plt.show()

# %%
fig,ax = plt.subplots(figsize=(12,6))
ax = sns.lineplot(data = data_kualitas_udara[['tanggal','pm10']].set_index('tanggal').resample('Y').mean(), palette=['red'])
ax1 = sns.lineplot(data = data_kualitas_udara[['tanggal','so2']].set_index('tanggal').resample('Y').mean(), palette = ['green'])
ax2 = sns.lineplot(data = data_kualitas_udara[['tanggal','co']].set_index('tanggal').resample('Y').mean(), palette = ['blue'])
ax3 = sns.lineplot(data = data_kualitas_udara[['tanggal','no2']].set_index('tanggal').resample('Y').mean(), palette = ['black'])
ax4 = sns.lineplot(data = data_kualitas_udara[['tanggal','o3']].set_index('tanggal').resample('Y').mean(), palette = ['purple'])
plt.title('Penyebaran Partikulat tiap tahun (2017-2021)')
plt.grid()
plt.show()

# %%
def count_plot_year(data, year):
    plt.figure(figsize=(12,6))
    sns.countplot(x='categori',data=data[data['tanggal'].dt.year == year])
    plt.title('Distribusi Jenis Udara di tahun '+ str(year))
    plt.show()

# %%
count_plot_year(data_kualitas_udara, 2017)

# %%
count_plot_year(data_kualitas_udara, 2018)

# %%
count_plot_year(data_kualitas_udara, 2019)

# %%
count_plot_year(data_kualitas_udara, 2020)

# %%
count_plot_year(data_kualitas_udara, 2021)

# %%
fig,ax = plt.subplots(1,2,figsize=(20,8))
labels = 'SEDANG', 'BAIK', 'TIDAK SEHAT', 'SANGAT TIDAK SEHAT'
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
explode = (0.05,0.05,0.05,0.05)

data_used = data_kualitas_udara[data_kualitas_udara['tanggal'].dt.year.isin([2017,2018,2019])]['categori'].value_counts(normalize=True)

size = list(data_used.values)
sns.countplot(x='categori',data=data_kualitas_udara[data_kualitas_udara['tanggal'].dt.year.isin([2017,2018,2019])], ax=ax[1],
             palette=colors, order = data_used.index)
ax[0].pie(size, labels=labels, autopct='%1.1f%%', shadow=True, colors=colors, explode=explode)
plt.suptitle('Jenis Kualitas Udara Sebelum Pandemi (2017-2019)')
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,8))
labels = 'SEDANG', 'BAIK', 'TIDAK SEHAT'
colors = ['#ff9999','#66b3ff','#99ff99']
explode = (0.05,0.05,0.05)

data_used = data_kualitas_udara[data_kualitas_udara['tanggal'].dt.year.isin([2020,2021])]['categori'].value_counts(normalize=True)

size = list(data_used.values)
sns.countplot(x='categori',data=data_kualitas_udara[data_kualitas_udara['tanggal'].dt.year.isin([2020,2021])], ax=ax[1],
             palette=colors, order=data_used.index)
ax[0].pie(size, labels=labels, autopct='%1.1f%%', shadow=True, colors=colors, explode=explode)
plt.suptitle('Jenis Kualitas Udara Selama Pandemi (2020-2021)')
plt.show()

# %% [markdown]
# ### Correlation Analysis

# %%
data_kualitas_udara
# Out:
#         tanggal                           stasiun  pm10   so2    co    o3  \
# 0    2017-01-01                DKI1 (Bunderan HI)  63.0  34.0  25.0  21.0
# 1    2017-01-02                DKI1 (Bunderan HI)  16.0  32.0  16.0  19.0
# 2    2017-01-03                DKI1 (Bunderan HI)  18.0  32.0  17.0  20.0
# 3    2017-01-04                DKI1 (Bunderan HI)  24.0  32.0  22.0  20.0
# 4    2017-01-05                DKI1 (Bunderan HI)  29.0  32.0  25.0  14.0
# ...         ...                               ...   ...   ...   ...   ...
# 7932 2021-12-27  DKI5 (Kebon Jeruk) Jakarta Barat  54.0  36.0  14.0  21.0
# 7933 2021-12-28  DKI5 (Kebon Jeruk) Jakarta Barat  44.0  20.0  11.0  21.0
# 7934 2021-12-29  DKI5 (Kebon Jeruk) Jakarta Barat  34.0  28.0   8.0  25.0
# 7935 2021-12-30  DKI5 (Kebon Jeruk) Jakarta Barat  53.0  25.0  15.0  23.0
# 7936 2021-12-31  DKI5 (Kebon Jeruk) Jakarta Barat  60.0  28.0  19.0  30.0
#
#        no2   max critical categori
# 0      2.0  63.0     PM10   SEDANG
# ...

# %%
sns.scatterplot(x='pm10',y='so2',data=data_kualitas_udara,hue='categori')
plt.show()

# %%
sns.scatterplot(x='pm10',y='co',data=data_kualitas_udara,hue='categori')
plt.show()

# %%
sns.scatterplot(x='pm10',y='no2',data=data_kualitas_udara,hue='categori')
plt.show()
